# %% [markdown]
# # BASICS OF IMAGE PROCESSING

# %% [markdown]
# ## lenna.jpg

# %% [markdown]
# ## READ THE IMAGE

# %%
import numpy as np
from matplotlib.image import imread 
image = imread(r"C:\Users\madhu\Downloads\lenna.png")
image
# Out:
# array([[[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        [[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        [[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        ...,
#
#        [[0.32941177, 0.07058824, 0.23529412],
# ...

# %%
import cv2
import matplotlib.pyplot as plt
image = imread(r"C:\Users\madhu\Downloads\lenna.png")
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# ## RESIZE THE IMAGE

# %% [markdown]
# ## BY SETTING VALUES:

# %%
resized_image = cv2.resize(image, (100, 100))  # Resize to 500x500 pixels
plt.imshow(resized_image)
plt.axis('off')
plt.show()
print(resized_image)
# Out:
# [[[0.8745098  0.5370196  0.5203922 ]
#   [0.8901961  0.5297255  0.48839214]
#   [0.87803924 0.5203922  0.4364706 ]
#   ...
#   [0.74       0.34039217 0.36705884]
#   [0.81686276 0.4097255  0.4007843 ]
#   [0.90290195 0.5806275  0.47866666]]
#
#  [[0.883898   0.50928473 0.4213804 ]
#   [0.89096946 0.51532084 0.43083453]
#   [0.8823294  0.50269806 0.3996471 ]
#   ...
#   [0.78417253 0.3694196  0.3705412 ]
#   [0.71180236 0.32331297 0.3370008 ]
#   [0.3751059  0.09470118 0.2616753 ]]
#
#  [[0.88275295 0.51675296 0.42847058]
#   [0.8812078  0.51523143 0.4194353 ]
#   [0.8892941  0.5042353  0.4111765 ]
#   ...
#   [0.6959216  0.31219608 0.33984315]
#   [0.3569098  0.10755294 0.27793726]
#   [0.35618824 0.08705883 0.26177257]]
#
#  ...
#
#  [[0.40512943 0.14221177 0.275051  ]
#   [0.42024314 0.14405492 0.263051  ]
#   [0.47184315 0.21576472 0.3422353 ]
#   ...
#   [0.42219606 0.12705883 0.25780392]
#   [0.3917412  0.09454902 0.22743529]
#   [0.38929412 0.08884706 0.22256471]]
#
# ...

# %% [markdown]
# ## BY DIVING ITS SIZE(HEIGHT,WIDTH)

# %%
resized_image = cv2.resize(image, (int(image.shape[1] / 2), int(image.shape[0] /2)))
plt.imshow(resized_image)
plt.axis('off')
plt.show()
print(resized_image)
# Out:
# [[[0.8862745  0.5372549  0.49019608]
#   [0.8745098  0.5352942  0.51176476]
#   [0.8862745  0.5235294  0.4627451 ]
#   ...
#   [0.9019608  0.57058823 0.5       ]
#   [0.9098039  0.582353   0.48039216]
#   [0.82549024 0.4490196  0.39215687]]
#
#  [[0.8862745  0.5372549  0.49019608]
#   [0.8745098  0.5352942  0.51176476]
#   [0.8862745  0.5235294  0.4627451 ]
#   ...
#   [0.9019608  0.57058823 0.5       ]
#   [0.9098039  0.582353   0.48039216]
#   [0.82549024 0.4490196  0.39215687]]
#
#  [[0.88823533 0.5431373  0.4862745 ]
#   [0.877451   0.52352947 0.4754902 ]
#   [0.88823533 0.5254902  0.4617647 ]
#   ...
#   [0.87058824 0.52254903 0.46470588]
#   [0.85294116 0.4911765  0.4254902 ]
#   [0.7137255  0.34117648 0.35490197]]
#
#  ...
#
#  [[0.35490197 0.11176471 0.24117649]
#   [0.35784316 0.11176471 0.2392157 ]
#   [0.38235295 0.11568628 0.24803923]
#   ...
#   [0.54901963 0.20784314 0.28137255]
#   [0.62254906 0.24607843 0.28921568]
#   [0.6333333  0.23333335 0.29313725]]
#
# ...

# %% [markdown]
# ## DIMENSIONS OF THE IMAGE

# %%
height, width, channels = image.shape
print("height:",height)
print("width:",width)
print("channel:",channels)
# Out:
# height: 512
# width: 512
# channel: 3

# %% [markdown]
# ## CONVERTING BGR TO RGB

# %% [markdown]
# ## WITH INBULIT FUNCTION

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
plt.imshow(image_rgb)
plt.axis('off')
plt.show()
print(image_rgb)
# Out:
# [[[0.49019608 0.5372549  0.8862745 ]
#   [0.49019608 0.5372549  0.8862745 ]
#   [0.52156866 0.5372549  0.8745098 ]
#   ...
#   [0.47843137 0.5803922  0.9019608 ]
#   [0.43137255 0.50980395 0.8666667 ]
#   [0.3529412  0.3882353  0.78431374]]
#
#  [[0.49019608 0.5372549  0.8862745 ]
#   [0.49019608 0.5372549  0.8862745 ]
#   [0.52156866 0.5372549  0.8745098 ]
#   ...
#   [0.47843137 0.5803922  0.9019608 ]
#   [0.43137255 0.50980395 0.8666667 ]
#   [0.3529412  0.3882353  0.78431374]]
#
#  [[0.49019608 0.5372549  0.8862745 ]
#   [0.49019608 0.5372549  0.8862745 ]
#   [0.52156866 0.5372549  0.8745098 ]
#   ...
#   [0.47843137 0.5803922  0.9019608 ]
#   [0.43137255 0.50980395 0.8666667 ]
#   [0.3529412  0.3882353  0.78431374]]
#
#  ...
#
#  [[0.23529412 0.07058824 0.32941177]
#   [0.23529412 0.07058824 0.32941177]
#   [0.22745098 0.10588235 0.36078432]
#   ...
#   [0.32941177 0.28627452 0.6784314 ]
#   [0.29803923 0.26666668 0.6745098 ]
#   [0.30980393 0.24313726 0.69411767]]
#
# ...

# %% [markdown]
# ## WITHOUT INBULIT FUNCTIONS:

# %%
import cv2
import matplotlib.pyplot as plt
image_rgb = image[:, :, [2, 1, 0]]
plt.imshow(image_rgb)
plt.axis('off') 
plt.show()
print(image_rgb)
# Out:
# [[[0.49019608 0.5372549  0.8862745 ]
#   [0.49019608 0.5372549  0.8862745 ]
#   [0.52156866 0.5372549  0.8745098 ]
#   ...
#   [0.47843137 0.5803922  0.9019608 ]
#   [0.43137255 0.50980395 0.8666667 ]
#   [0.3529412  0.3882353  0.78431374]]
#
#  [[0.49019608 0.5372549  0.8862745 ]
#   [0.49019608 0.5372549  0.8862745 ]
#   [0.52156866 0.5372549  0.8745098 ]
#   ...
#   [0.47843137 0.5803922  0.9019608 ]
#   [0.43137255 0.50980395 0.8666667 ]
#   [0.3529412  0.3882353  0.78431374]]
#
#  [[0.49019608 0.5372549  0.8862745 ]
#   [0.49019608 0.5372549  0.8862745 ]
#   [0.52156866 0.5372549  0.8745098 ]
#   ...
#   [0.47843137 0.5803922  0.9019608 ]
#   [0.43137255 0.50980395 0.8666667 ]
#   [0.3529412  0.3882353  0.78431374]]
#
#  ...
#
#  [[0.23529412 0.07058824 0.32941177]
#   [0.23529412 0.07058824 0.32941177]
#   [0.22745098 0.10588235 0.36078432]
#   ...
#   [0.32941177 0.28627452 0.6784314 ]
#   [0.29803923 0.26666668 0.6745098 ]
#   [0.30980393 0.24313726 0.69411767]]
#
# ...

# %% [markdown]
# ## CONVERTING BGR TO GRAY

# %% [markdown]
# ## WITH INBULIT FUNCTION

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
print(gray_image)
# Out:
# [[0.56297255 0.56297255 0.5710118  ... 0.5865647  0.5270353  0.4228353 ]
#  [0.56297255 0.56297255 0.5710118  ... 0.5865647  0.5270353  0.4228353 ]
#  [0.56297255 0.56297255 0.5710118  ... 0.5865647  0.5270353  0.4228353 ]
#  ...
#  [0.14934118 0.14934118 0.1712902  ... 0.34387845 0.3225412  0.31448236]
#  [0.15413725 0.15413725 0.18927844 ... 0.33379218 0.33933336 0.34802747]
#  [0.15413725 0.15413725 0.18927844 ... 0.33379218 0.33933336 0.34802747]]

# %% [markdown]
# ## WITHOUT INBUILT FUNCTION

# %% [markdown]
# ## histogram equalization

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread((r"C:\Users\madhu\Downloads\lenna.png"))

# Check if image is loaded properly
if image is None:
    print("Error: Image not loaded. Check file path!")
else:
    # Convert to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Normalize if necessary
    if gray_image.max() > 1:
        gray_image = cv2.normalize(gray_image, None, 0, 255, cv2.NORM_MINMAX).astype('uint8')

    # Equalize histogram
    equalized_image = cv2.equalizeHist(gray_image)

    
    plt.figure(figsize=(12, 6))

    plt.subplot(2, 3, 1)
    plt.title("Original Grayscale Image")
    plt.imshow(gray_image, cmap='gray')
    plt.axis('off')

    plt.subplot(2, 3, 2)
    plt.title("Histogram Equalized Image")
    plt.imshow(equalized_image, cmap='gray')
    plt.axis('off')
    plt.subplot(2, 3, 4)
    plt.title("Histogram of Original Image")
    plt.hist(gray_image.flatten(), bins=256, range=[0, 256], color='blue')

    plt.subplot(2, 3, 5)
    plt.title("Histogram of Equalized Image")
    plt.hist(equalized_image.flatten(), bins=256, range=[0, 256], color='red')

    plt.show()

# %%
gray_image = 0.2989*image[:,:,2] + 0.5870*image[:,:,1] + 0.1140*image[:,:,0]

hist, bins = np.histogram(gray_image.flatten(), bins=256, range=[0, 256])

cdf = hist.cumsum()

cdf_normalized = cdf * 255 / cdf.max()

equalized_image = np.interp(gray_image.flatten(), bins[:-1], cdf_normalized)

equalized_image = equalized_image.reshape(gray_image.shape)


plt.title('Original Grayscale Image')
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.show()


plt.title('Histogram of Original Image')
plt.plot(hist, color='blue')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.show()


plt.title('Histogram Equalized Image')
plt.imshow(equalized_image, cmap='gray')
plt.axis('off')
plt.show()


equalized_hist, _ = np.histogram(equalized_image.flatten(), bins=256, range=[0, 256])

plt.title('Histogram of Equalized Image')
plt.plot( equalized_hist, color='red')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.show()
